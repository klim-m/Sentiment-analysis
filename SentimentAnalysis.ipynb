# %%
punctuation_chars = ["'", '"', ",", ".", "!", ":", ";", '#', '@']

#building punctuation stripper
def strip_punctuation(string):
    for punc in punctuation_chars:
        string = string.replace(punc, "")
    return string
        
print(strip_punctuation("#lo'se'r!"))
# Out:
# loser

# %%
positive_words_file = "/Users/mendo/Desktop/Python course 2- files, dictionaries/Practice files/Txtfiles/Exam- sentiment analysis/positive_words.txt"
negative_words_file = "/Users/mendo/Desktop/Python course 2- files, dictionaries/Practice files/Txtfiles/Exam- sentiment analysis/negative_words.txt"

positive_words = []
with open(positive_words_file) as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            positive_words.append(lin.strip())
            
def get_pos(string):
    
    string = string.lower()
    new_string = strip_punctuation(string)
    list_of_string= new_string.split(" ")
    #print(string)
    count = 0
    for pos in positive_words:
        for word in list_of_string:
            if (word == pos):
                count +=1
    return count
    
negative_words = []
with open(negative_words_file) as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            negative_words.append(lin.strip())

def get_neg(string):
    string = string.lower()
    new_string = strip_punctuation(string)
    list_of_string = new_string.split(" ")
    count = 0
    for neg in negative_words:
        for word in list_of_string:
            if (word == neg):
                count +=1
    return count

# %%
twitter_data_file = "/Users/mendo/Desktop/Python course 2- files, dictionaries/Practice files/Txtfiles/Exam- sentiment analysis/project_twitter_data.txt"


punctuation_chars = ["'", '"', ",", ".", "!", ":", ";", '#', '@']
# lists of words to use
def strip_punctuation(string):
    for punc in punctuation_chars:
        string = string.replace(punc, "")
    return string

positive_words = []
with open(positive_words_file) as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            positive_words.append(lin.strip())
            
def get_pos(string):
    
    string = string.lower()
    new_string = strip_punctuation(string)
    list_of_string= new_string.split(" ")
    #print(string)
    count = 0
    for pos in positive_words:
        for word in list_of_string:
            if (word == pos):
                count +=1
    return count
    
negative_words = []
with open(negative_words_file) as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            negative_words.append(lin.strip())
            
def get_neg(string):
    string = string.lower()
    new_string = strip_punctuation(string)
    list_of_string = new_string.split(" ")
    count = 0
    for neg in negative_words:
        for word in list_of_string:
            if (word == neg):
                count +=1
    return count 

resulting_data_file = "/Users/mendo/Desktop/Python course 2- files, dictionaries/Practice files/Txtfiles/Exam- sentiment analysis/resulting_data.txt"
wt= open(resulting_data_file, "w")
wt.write("Number of Retweets, Number of Replies, Positive Score, Negative Score, Net Score")
wt.write("\n")
    
with open(twitter_data_file, "r") as rt:
    content = rt.read()
    #print(content)
    lines = rt.readlines()
    #print(lines)
    for line in lines:
        contents = line.strip()
        #print(contents)
    
    for row in lines[1:]: 		#only from 2nd line onwards 
        values = row.strip().split(',')
        p_score = get_pos(row)
        n_score = get_neg(row)
        net_score= p_score - n_score
        data = "{},{},{},{}, {}".format(values[1], values[2], p_score, n_score, net_score)
        #print(data)
        wt.write(data)
        wt.write("\n")

# %%
twitter_data_file = "/Users/mendo/Desktop/Python course 2- files, dictionaries/Practice files/Txtfiles/Exam- sentiment analysis/project_twitter_data.txt"


punctuation_chars = ["'", '"', ",", ".", "!", ":", ";", '#', '@']
# lists of words to use
def strip_punctuation(string):
    for punc in punctuation_chars:
        string = string.replace(punc, "")
    return string

positive_words = []
with open(positive_words_file) as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            positive_words.append(lin.strip())
            
def get_pos(string):
    
    string = string.lower()
    new_string = strip_punctuation(string)
    list_of_string= new_string.split(" ")
    #print(string)
    count = 0
    for pos in positive_words:
        for word in list_of_string:
            if (word == pos):
                count +=1
    return count
    
negative_words = []
with open(negative_words_file) as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            negative_words.append(lin.strip())
            
def get_neg(string):
    string = string.lower()
    new_string = strip_punctuation(string)
    list_of_string = new_string.split(" ")
    count = 0
    for neg in negative_words:
        for word in list_of_string:
            if (word == neg):
                count +=1
    return count 

resulting_data_file = "/Users/mendo/Desktop/Python course 2- files, dictionaries/Practice files/Txtfiles/Exam- sentiment analysis/resulting_data.txt"
wt= open(resulting_data_file, "w")
wt.write("Number of Retweets, Number of Replies, Positive Score, Negative Score, Net Score")
wt.write("\n")
    
with open(twitter_data_file, "r") as rt:
    content = rt.read()
    #print(content)
    lines = rt.readlines()
    #print(lines)
    for line in lines:
        contents = line.strip()
        #print(contents)
    
    for row in lines[1:]: 		#only from 2nd line onwards 
        values = row.strip().split(',')
        p_score = get_pos(row)
        n_score = get_neg(row)
        net_score= p_score - n_score
        data = "{},{},{},{}, {}".format(values[1], values[2], p_score, n_score, net_score)
        print(data)
        #wt.write(data)
        #wt.write("\n")

# %%
twitter_data_file = "/Users/mendo/Desktop/Python course 2- files, dictionaries/Practice files/Txtfiles/Exam- sentiment analysis/project_twitter_data.txt"

with open(twitter_data_file, "r") as rt:
    content = rt.read()
    #print(content)
    #lines = rt.readlines()
    #print(lines)
    #for line in lines:
     #   contents = line.strip()
      #  #print(contents)
    
    for row in lines[1:]: 		#only from 2nd line onwards 
        values = row.strip().split(',')
        p_score = get_pos(row)
        n_score = get_neg(row)
        net_score= p_score - n_score
        data = "{},{},{},{}, {}".format(values[1], values[2], p_score, n_score, net_score)
        print(data)
# Out:
# []
